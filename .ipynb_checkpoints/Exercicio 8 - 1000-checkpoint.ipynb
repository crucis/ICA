# %% [markdown]
# # Exercício 8 de Análise de Componentes Independentes
# Pedro Bandeira de Mello Martins
#
# CPE 782 - Análise de Componentes Independentes
#
#
#
# Análise feita para 1000 amostras

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.linalg import inv
from scipy.cluster.vq import whiten
import pandas as pd
from pandas.plotting import scatter_matrix
from scipy.stats import entropy, chi2_contingency, shapiro

# %matplotlib inline
from evaluation import calculateNegentropy, kde_entropy, KLdivergence, resultsTable, plot_MutualInformation
from ICAfunctions import cichocki_Feedback, cichocki_Feedforward, NPCA_RLS

#Notes:
#SHAPIRO: The algorithm used is described in [R634] but censoring parameters as 
#        described are not implemented. For N > 5000 the W test statistic is 
#        accurate but the p-value may not be.

# %%
learning_rate = 1e-6
gaussian_distribution = np.random.normal(0,1,1000)
shapiro(np.random.uniform(-1,1,1000))
# Out:
# (0.9529117941856384, 2.275890344435742e-17)

# %%
filePath = 'https://raw.githubusercontent.com/micaelverissimo/ICA/master/EighthMixture1000Stats.txt'
distDataFrame = pd.read_table(filePath, delimiter = '\s+', header = None)
mixtures = distDataFrame.values
print(distDataFrame.T.head())
# Out:
#           0           1          2         3         4
# 0  0.175656  136.227737   1.383841  0.903917  2.553519
# 1  0.387781  266.015362   0.495886  1.076020  5.108833
# 2  0.859429   13.867414   0.502838  1.218883  8.100403
# 3  2.285493    3.156261  13.011482  0.010587  1.759430
# 4  1.771595    3.946307   1.477723  0.705542  3.189165

# %%
scatter_matrix(distDataFrame.T, alpha=0.4, diagonal = 'kde', figsize = (10,10))
plt.show()

# %%
resultsTable(mixtures)
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  Data</th><th style="text-align: right;">  Negentropy</th><th style="text-align: right;">  KL Divergence</th><th style="text-align: right;">  Shapiro-Wilk test W</th><th style="text-align: right;">  Shapiro-Wilk test P_value</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     0</td><td style="text-align: right;">      0.112 </td><td style="text-align: right;">         2.1526</td><td style="text-align: right;">               0.8321</td><td style="text-align: right;">                 3.8693e-31</td></tr>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;">      2.3909</td><td style="text-align: right;">         5.8012</td><td style="text-align: right;">               0.0121</td><td style="text-align: right;">                 0         </td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;">      1.0346</td><td style="text-align: right;">         4.1234</td><td style="text-align: right;">               0.7085</td><td style="text-align: right;">                 1.9135e-38</td></tr>
# <tr><td style="text-align: right;">     3</td><td style="text-align: right;">      2.6933</td><td style="text-align: right;">         6.8713</td><td style="text-align: right;">               0.0382</td><td style="text-align: right;">                 0         </td></tr>
# <tr><td style="text-align: right;">     4</td><td style="text-align: right;">      1.2401</td><td style="text-align: right;">         4.6188</td><td style="text-align: right;">               0.6401</td><td style="text-align: right;">                 1.8995e-41</td></tr>
# </tbody>
# </table>

# %% [markdown]
# ## NPCA-RLS Algorithm

# %%
[yNPCA, WNPCA] = NPCA_RLS(mixtures,runs = 1)

# %%
scatter_matrix(pd.DataFrame(yNPCA.T), alpha = 0.4, diagonal = 'kde', figsize = (10,10))
plt.show()

# %%
resultsTable(yNPCA)
plot_MutualInformation(mixtures, y = yNPCA, KDE = True)
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  Data</th><th style="text-align: right;">  Negentropy</th><th style="text-align: right;">  KL Divergence</th><th style="text-align: right;">  Shapiro-Wilk test W</th><th style="text-align: right;">  Shapiro-Wilk test P_value</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     0</td><td style="text-align: right;">      0.5673</td><td style="text-align: right;">         0.2503</td><td style="text-align: right;">               0.9674</td><td style="text-align: right;">                 3.466e-14 </td></tr>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;">      0.3171</td><td style="text-align: right;">         0.3402</td><td style="text-align: right;">               0.9846</td><td style="text-align: right;">                 9.4017e-09</td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;">      0.1004</td><td style="text-align: right;">         0.2736</td><td style="text-align: right;">               0.9691</td><td style="text-align: right;">                 9.4638e-14</td></tr>
# <tr><td style="text-align: right;">     3</td><td style="text-align: right;">      0.1968</td><td style="text-align: right;">         0.1511</td><td style="text-align: right;">               0.9716</td><td style="text-align: right;">                 4.3769e-13</td></tr>
# <tr><td style="text-align: right;">     4</td><td style="text-align: right;">      0.2355</td><td style="text-align: right;">         0.4318</td><td style="text-align: right;">               0.9871</td><td style="text-align: right;">                 1.0538e-07</td></tr>
# </tbody>
# </table>
# C:\Users\Pedro\Anaconda3\lib\site-packages\statsmodels\sandbox\distributions\mv_measures.py:47: RuntimeWarning: invalid value encountered in sqrt
#   mi_normed = np.sqrt(1. - np.exp(-2 * mi))

# %% [markdown]
# ## Chichocki-Unbehauen Algorithm Feedback network

# %%
[yFeedback, WFeedback] = cichocki_Feedback(mixtures, learningRate = 1e-3, decayRate = 1e-7, runs  = 100)

# %%
scatter_matrix(pd.DataFrame(yFeedback.T), alpha = 0.4, diagonal = 'kde', figsize = (10,10))
plt.show()

# %%
resultsTable(yFeedback)
plot_MutualInformation(mixtures, y = yFeedback, KDE = True)
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  Data</th><th style="text-align: right;">  Negentropy</th><th style="text-align: right;">  KL Divergence</th><th style="text-align: right;">  Shapiro-Wilk test W</th><th style="text-align: right;">  Shapiro-Wilk test P_value</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     0</td><td style="text-align: right;">      0.7751</td><td style="text-align: right;">         0.7358</td><td style="text-align: right;">               0.8046</td><td style="text-align: right;">                 4.5417e-33</td></tr>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;">      0.6486</td><td style="text-align: right;">         2.4986</td><td style="text-align: right;">               0.8246</td><td style="text-align: right;">                 1.0929e-31</td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;">      0.8175</td><td style="text-align: right;">         1.2348</td><td style="text-align: right;">               0.7752</td><td style="text-align: right;">                 6.6772e-35</td></tr>
# <tr><td style="text-align: right;">     3</td><td style="text-align: right;">      0.742 </td><td style="text-align: right;">         7.2972</td><td style="text-align: right;">               0.6879</td><td style="text-align: right;">                 2.0955e-39</td></tr>
# <tr><td style="text-align: right;">     4</td><td style="text-align: right;">      0.5802</td><td style="text-align: right;">         1.1248</td><td style="text-align: right;">               0.7925</td><td style="text-align: right;">                 7.6028e-34</td></tr>
# </tbody>
# </table>
# C:\Users\Pedro\Anaconda3\lib\site-packages\statsmodels\sandbox\distributions\mv_measures.py:47: RuntimeWarning: invalid value encountered in sqrt
#   mi_normed = np.sqrt(1. - np.exp(-2 * mi))

# %% [markdown]
# ## Chichocki-Unbehauen Algorithm Feedforward network

# %%
[yFeedforward, WFeedforward] = cichocki_Feedforward(mixtures, learningRate = 1e-8, runs = 100)

# %%
scatter_matrix(pd.DataFrame(yFeedforward.T), alpha = 0.4, diagonal = 'kde', figsize = (10,10))
plt.show()

# %%
resultsTable(yFeedforward)
plot_MutualInformation(mixtures, y = yFeedforward, KDE = True)
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  Data</th><th style="text-align: right;">  Negentropy</th><th style="text-align: right;">  KL Divergence</th><th style="text-align: right;">  Shapiro-Wilk test W</th><th style="text-align: right;">  Shapiro-Wilk test P_value</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     0</td><td style="text-align: right;">      1.5254</td><td style="text-align: right;">        17.4999</td><td style="text-align: right;">               0.5653</td><td style="text-align: right;">                 3.0829e-44</td></tr>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;">      0.8904</td><td style="text-align: right;">         0.7663</td><td style="text-align: right;">               0.7561</td><td style="text-align: right;">                 5.3548e-36</td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;">      1.2968</td><td style="text-align: right;">         4.7729</td><td style="text-align: right;">               0.5751</td><td style="text-align: right;">                 6.8664e-44</td></tr>
# <tr><td style="text-align: right;">     3</td><td style="text-align: right;">      1.1048</td><td style="text-align: right;">        28.2214</td><td style="text-align: right;">               0.5586</td><td style="text-align: right;">                 1.8217e-44</td></tr>
# <tr><td style="text-align: right;">     4</td><td style="text-align: right;">      0.7283</td><td style="text-align: right;">         2.4542</td><td style="text-align: right;">               0.7712</td><td style="text-align: right;">                 3.8867e-35</td></tr>
# </tbody>
# </table>
# C:\Users\Pedro\Anaconda3\lib\site-packages\statsmodels\sandbox\distributions\mv_measures.py:47: RuntimeWarning: invalid value encountered in sqrt
#   mi_normed = np.sqrt(1. - np.exp(-2 * mi))
