td></tr>
# <tr><td style="text-align: right;">     4</td><td style="text-align: right;">      1.1095</td><td style="text-align: right;">        28.9353</td><td style="text-align: right;">               0.7089</td><td style="text-align: right;">                 2.0158e-38</td></tr>
# </tbody>
# </table>
# C:\Users\Pedro\Anaconda3\lib\site-packages\statsmodels\sandbox\distributions\mv_measures.py:47: RuntimeWarning: invalid value encountered in sqrt
#   mi_normed = np.sqrt(1. - np.exp(-2 * mi))

# %% [markdown]
# # Hipóteses de PDF

# %%
from evaluation import graph_fittedData

# %% [markdown]
# Aqui o objetivo é encontrar PDFs que representem as fontes encontradas. Utiliza-se uma função que testa todas as funções de densidade probabilística implementadas no pacote SciPy em Python e verifica qual das hipóteses tem o menor $\chi ^2$.

# %% [markdown]
# ## NPCA-RLS Algorithm

# %%
for i, y in enumerate(yNPCA):
    graph_fittedData(y)

# %% [markdown]
# ## Chichocki-Unbehauen Algorithm Feedback network

# %%
for i, y in enumerate(yFeedback):
    graph_fittedData(y)

# %% [markdown]
# ## Chichocki-Unbehauen Algorithm Feedforward network

# %%
for i, y in enumerate(yFeedforward):
    graph_fittedData(y)

# %% [markdown]
# # Fontes conhecidas

# %%
filePathSource = 'https://raw.githubusercontent.com/micaelverissimo/ICA/master/Mixture_keys/EighthSource1000Stats.txt'
distDataFrameSources = pd.read_table(filePathSource, delimiter = '\s+', header = None)
mixtures = distDataFrame.values
print(distDataFrame.shape)
distDataFrame.T.head()
# Out:
# (5, 1000)
#           0           1          2         3         4
# 0  0.175656  136.227737   1.383841  0.903917  2.553519
# 1  0.387781  266.015362   0.495886  1.076020  5.108833
# 2  0.859429   13.867414   0.502838  1.218883  8.100403
# 3  2.285493    3.156261  13.011482  0.010587  1.759430
# 4  1.771595    3.946307   1.477723  0.705542  3.189165

# %%
scatter_matrix(distDataFrameSources.T, alpha=0.4, diagonal = 'kde', figsize = (10,10))
plt.show()

# %% [markdown]
# ## NPCA-RLS

# %%
from evaluation import KLmatrix, MImatrix
KLmatrix(distDataFrameSources.values,yNPCA)
MImatrix(distDataFrameSources.values,yNPCA)
# Out:
# (5, 1000) (5, 1000)
# [[  1.36825434   8.42007061   4.22957923   5.91814644   4.07817549]
#  [ 10.94963588  13.87461473   2.01691081   1.33332118   0.29688701]
#  [  1.93074067   7.24028073   6.12011912   3.46788156   5.08424826]
#  [  3.06822189   2.33038398   2.83693355   1.14068923   6.02879498]
#  [  5.13665504   8.40061538   1.44946396   0.79150096   1.40596344]]
# C:\Users\Pedro\Anaconda3\lib\site-packages\statsmodels\sandbox\distributions\mv_measures.py:47: RuntimeWarning: invalid value encountered in sqrt
#   mi_normed = np.sqrt(1. - np.exp(-2 * mi))

# %% [markdown]
# ## Chichocki-Unbehauen Algorithm Feedback network

# %%
KLmatrix(distDataFrameSources.values,yFeedback)
MImatrix(distDataFrameSources.values,yFeedback)
# Out:
# (5, 1000) (5, 1000)
# [[ 16.98807374  16.10749097   6.19046462   3.72949392   6.91418423]
#  [ 20.83911273  13.79346675   1.19833783   7.79891182   1.33500253]
#  [ 20.24741742  21.47205631   8.03696381   1.90976997  12.14680475]
#  [ 20.52996469  22.62284386   5.13564543   0.56751002  11.9394065 ]
#  [ 19.72246465  18.03353033   2.25808927   2.5064456    3.51030286]]
# C:\Users\Pedro\Anaconda3\lib\site-packages\statsmodels\sandbox\distributions\mv_measures.py:47: RuntimeWarning: invalid value encountered in sqrt
#   mi_normed = np.sqrt(1. - np.exp(-2 * mi))

# %% [markdown]
# ## Chichocki-Unbehauen Algorithm Feedforward network

# %%
KLmatrix(distDataFrameSources.values,yFeedforward)
MImatrix(distDataFrameSources.values,yFeedforward)
# Out:
# (5, 1000) (5, 1000)
# [[ 20.20835874  18.56099478   2.60303866   0.53212406   2.35819468]
#  [ 23.44914605  16.78042179   0.95050521   0.6006499    0.5500565 ]
#  [ 24.38790168  23.53993176   9.44531546   0.71878803   5.68895811]
#  [ 25.01926462  24.67063687  10.87753187   1.06335432   6.85209711]
#  [ 23.88965811  20.4855415    3.49102562   0.23551203   1.9246787 ]]
# C:\Users\Pedro\Anaconda3\lib\site-packages\statsmodels\sandbox\distributions\mv_measures.py:47: RuntimeWarning: invalid value encountered in sqrt
#   mi_normed = np.sqrt(1. - np.exp(-2 * mi))
