# %% [markdown]
# # Exercício 4 de Análise de Componentes Independentes
# Pedro Bandeira de Mello Martins
#
# CPE 782 - Análise de Componentes Independentes
#
#
#
# Análise feita para 100000 amostras

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.linalg import inv
from scipy.cluster.vq import whiten
import pandas as pd
from pandas.plotting import scatter_matrix
from scipy.stats import entropy, chi2_contingency, shapiro

# %matplotlib inline
from evaluation import calculateNegentropy, kde_entropy, KLdivergence, resultsTable, plot_MutualInformation
from ICAfunctions import cichocki_Feedback, cichocki_Feedforward, NPCA_RLS

#Notes:
#SHAPIRO: The algorithm used is described in [R634] but censoring parameters as 
#        described are not implemented. For N > 5000 the W test statistic is 
#        accurate but the p-value may not be.

# %%
learning_rate = 1e-6
gaussian_distribution = np.random.normal(0,1,1000)
shapiro(np.random.uniform(-1,1,1000))
# Out:
# (0.9528943300247192, 2.2581273025256557e-17)

# %%
filePath = 'https://raw.githubusercontent.com/micaelverissimo/ICA/master/FourthMixture100000Stats.txt'
distDataFrame = pd.read_table(filePath, delimiter = '\s+', header = None)
mixtures = distDataFrame.values
print(distDataFrame.T.head())
# Out:
#            0         1         2         3         4
# 0  -1.878596 -2.283238  2.023197  4.188460 -0.568429
# 1  -4.770146 -3.943429  3.038668  5.987318 -1.346351
# 2 -12.223103 -7.609984  6.246506  9.677850 -8.188600
# 3  -0.947095 -3.722046  2.863110  7.628454 -1.373400
# 4  -1.803100  0.172723  0.859307  0.167935 -2.742939

# %%
scatter_matrix(distDataFrame.T, alpha=0.4, diagonal = 'kde', figsize = (10,10))
plt.show()

# %%
resultsTable(mixtures)
# Out:
# C:\Users\Pedro\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1326: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# <table>
# <thead>
# <tr><th style="text-align: right;">  Data</th><th style="text-align: right;">  Negentropy</th><th style="text-align: right;">  KL Divergence</th><th style="text-align: right;">  Shapiro-Wilk test W</th><th style="text-align: right;">  Shapiro-Wilk test P_value</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     0</td><td style="text-align: right;">      0.1237</td><td style="text-align: right;">         0.744 </td><td style="text-align: right;">               0.973 </td><td style="text-align: right;">                          0</td></tr>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;">      0.3549</td><td style="text-align: right;">         2.2868</td><td style="text-align: right;">               0.9298</td><td style="text-align: right;">                          0</td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;">      0.331 </td><td style="text-align: right;">         3.349 </td><td style="text-align: right;">               0.9105</td><td style="text-align: right;">                          0</td></tr>
# <tr><td style="text-align: right;">     3</td><td style="text-align: right;">      0.2928</td><td style="text-align: right;">         1.9347</td><td style="text-align: right;">               0.9571</td><td style="text-align: right;">                          0</td></tr>
# <tr><td style="text-align: right;">     4</td><td style="text-align: right;">      0.0343</td><td style="text-align: right;">         0.95  </td><td style="text-align: right;">               0.9891</td><td style="text-align: right;">                          0</td></tr>
# </tbody>
# </table>

# %% [markdown]
# ## NPCA-RLS Algorithm

# %%
[yNPCA, WNPCA] = NPCA_RLS(mixtures, runs = 1)
# Out:
# Execution time: 7.44544529914856 seconds

# %%
scatter_matrix(pd.DataFrame(yNPCA.T), alpha = 0.4, diagonal = 'kde', figsize = (10,10))
plt.show()

# %%
resultsTable(yNPCA)
plot_MutualInformation(mixtures[-1000:], y = yNPCA[-1000:], KDE = False)
# Out:
# C:\Users\Pedro\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1326: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# <table>
# <thead>
# <tr><th style="text-align: right;">  Data</th><th style="text-align: right;">  Negentropy</th><th style="text-align: right;">  KL Divergence</th><th style="text-align: right;">  Shapiro-Wilk test W</th><th style="text-align: right;">  Shapiro-Wilk test P_value</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     0</td><td style="text-align: right;">      4.2034</td><td style="text-align: right;">         7.76  </td><td style="text-align: right;">               0.0046</td><td style="text-align: right;">                          0</td></tr>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;">      4.2951</td><td style="text-align: right;">         7.4546</td><td style="text-align: right;">               0.0074</td><td style="text-align: right;">                          0</td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;">      4.2197</td><td style="text-align: right;">         7.2449</td><td style="text-align: right;">               0.0077</td><td style="text-align: right;">                          0</td></tr>
# <tr><td style="text-align: right;">     3</td><td style="text-align: right;">      4.321 </td><td style="text-align: right;">         6.6622</td><td style="text-align: right;">               0.0041</td><td style="text-align: right;">                          0</td></tr>
# <tr><td style="text-align: right;">     4</td><td style="text-align: right;">      4.257 </td><td style="text-align: right;">         4.4296</td><td style="text-align: right;">               0.0087</td><td style="text-align: right;">                          0</td></tr>
# </tbody>
# </table>
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-8-2a93c4331422> in <module>()
#       1 resultsTable(yNPCA)
# ----> 2 plot_MutualInformation(mixtures[-1000:], y = yNPCA[-1000:], KDE = False)
#
# E:\OneDrive\Documentos\UFRJ\Mestrado\PEE\ICA\funcoes\evaluation.py in plot_MutualInformation(mixtures, y, KDE, nbins)
#     132     axs[0].set_title('Mutual Information: mixed signals')
#     133
# --> 134     sb.heatmap(mutualInformation_matrix(y, kde = KDE, n_bins = nbins), ax=axs[1], annot=True, cmap = 'YlGnBu', vmin = 0, vmax = 1)
#     135     axs[1].set_title('Mutual Information: outputs')
#     136
#
# E:\OneDrive\Documentos\UFRJ\Mestrado\PEE\ICA\funcoes\evaluation.py in mutualInformation_matrix(signal, kde, n_bins)
#     103                 fx, binsx = np.histogram(p, bins = p_bins)
#     104                 fy, binsy = np.histogram(q, bins = q_bins)
# --> 105                 fyx, binsy, binsx = np.histogram2d(q, p, bins = (binsy, binsx))
#     106
#     107                 pyx = fyx * 1. / cols
#
# C:\Users\Pedro\Anaconda3\lib\site-packages\numpy\lib\twodim_base.py in histogram2d(x, y, bins, range, normed, weights)
#     647         xedges = yedges = asarray(bins, float)
#     648         bins = [xedges, yedges]
# --> 649     hist, edges = histogramdd([x, y], bins, range, normed, weights)
#     650     return hist, edges[0], edges[1]
#     651
#
# C:\Users\Pedro\Anaconda3\lib\site-packages\numpy\lib\function_base.py in histogramdd(sample, bins, range, normed, weights)
#     975     # Reshape is used so that overlarge arrays
#     976     # will raise an error.
# --> 977     hist = zeros(nbin, float).reshape(-1)
#     978
#     979     # Compute the sample indices in the flattened histogram matrix.
#
# MemoryError:

# %% [markdown]
# ## Chichocki-Unbehauen Algorithm Feedback network

# %%
[yFeedback, WFeedback] = cichocki_Feedback(mixtures, runs  = 1)
# Out:
# Execution time: 10.129138708114624 seconds

# %%
scatter_matrix(pd.DataFrame(yFeedback.T), alpha = 0.4, diagonal = 'kde', figsize = (10,10))
plt.show()

# %%
resultsTable(yFeedback)
plot_MutualInformation(mixtures[-1000:], y = yFeedback[-1000:], KDE = False)
# Out:
# C:\Users\Pedro\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1326: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# <table>
# <thead>
# <tr><th style="text-align: right;">  Data</th><th style="text-align: right;">  Negentropy</th><th style="text-align: right;">  KL Divergence</th><th style="text-align: right;">  Shapiro-Wilk test W</th><th style="text-align: right;">  Shapiro-Wilk test P_value</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     0</td><td style="text-align: right;">      0.3021</td><td style="text-align: right;">         3.7105</td><td style="text-align: right;">               0.9144</td><td style="text-align: right;">                 0         </td></tr>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;">      0.0201</td><td style="text-align: right;">         0.0312</td><td style="text-align: right;">               0.9983</td><td style="text-align: right;">                 1.1382e-28</td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;">      0.2101</td><td style="text-align: right;">         0.0354</td><td style="text-align: right;">               0.9991</td><td style="text-align: right;">                 4.2878e-21</td></tr>
# <tr><td style="text-align: right;">     3</td><td style="text-align: right;">      0.0753</td><td style="text-align: right;">         0.0371</td><td style="text-align: right;">               0.9967</td><td style="text-align: right;">                 2.3039e-38</td></tr>
# <tr><td style="text-align: right;">     4</td><td style="text-align: right;">      0     </td><td style="text-align: right;">         0.0402</td><td style="text-align: right;">               0.998 </td><td style="text-align: right;">                 6.5289e-31</td></tr>
# </tbody>
# </table>

# %% [markdown]
# ## Chichocki-Unbehauen Algorithm Feedforward network

# %%
[yFeedforward, WFeedforward] = cichocki_Feedforward(mixtures, learningRate = 1e-11, runs = 1)
# Out:
# Execution time: 6.802899599075317 seconds

# %%
scatter_matrix(pd.DataFrame(yFeedforward.T), alpha = 0.4, diagonal = 'kde', figsize = (10,10))
plt.show()

# %%
resultsTable(yFeedforward)
plot_MutualInformation(mixtures[-1000:], y = yFeedforward[-1000:], KDE = False)
# Out:
# C:\Users\Pedro\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1326: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# <table>
# <thead>
# <tr><th style="text-align: right;">  Data</th><th style="text-align: right;">  Negentropy</th><th style="text-align: right;">  KL Divergence</th><th style="text-align: right;">  Shapiro-Wilk test W</th><th style="text-align: right;">  Shapiro-Wilk test P_value</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     0</td><td style="text-align: right;">      0.2762</td><td style="text-align: right;">         3.8756</td><td style="text-align: right;">               0.9155</td><td style="text-align: right;">                 0         </td></tr>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;">      0.1558</td><td style="text-align: right;">         0.0256</td><td style="text-align: right;">               0.9992</td><td style="text-align: right;">                 1.6441e-19</td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;">      0.1408</td><td style="text-align: right;">         0.0182</td><td style="text-align: right;">               0.9996</td><td style="text-align: right;">                 1.1867e-13</td></tr>
# <tr><td style="text-align: right;">     3</td><td style="text-align: right;">      0.1901</td><td style="text-align: right;">         0.0506</td><td style="text-align: right;">               0.9978</td><td style="text-align: right;">                 2.2248e-32</td></tr>
# <tr><td style="text-align: right;">     4</td><td style="text-align: right;">      0     </td><td style="text-align: right;">         0.183 </td><td style="text-align: right;">               0.9969</td><td style="text-align: right;">                 1.4414e-37</td></tr>
# </tbody>
# </table>
