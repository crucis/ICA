></tr>
# <tr><td style="text-align: right;">     3</td><td style="text-align: right;">       0    </td><td style="text-align: right;">         0.063 </td><td style="text-align: right;">               0.9987</td><td style="text-align: right;">                 0.67198   </td></tr>
# <tr><td style="text-align: right;">     4</td><td style="text-align: right;">       0    </td><td style="text-align: right;">         0.1167</td><td style="text-align: right;">               0.9967</td><td style="text-align: right;">                 0.034588  </td></tr>
# </tbody>
# </table>

# %% [markdown]
# # Hipóteses de PDF

# %% [markdown]
# Aqui o objetivo é encontrar PDFs que representem as fontes encontradas. Utiliza-se uma função que testa todas as funções de densidade probabilística implementadas no pacote SciPy em Python e verifica qual das hipóteses tem o menor $\chi ^2$.

# %% [markdown]
# ## NPCA-RLS Algorithm

# %%
for i, y in enumerate(yNPCA):
    graph_fittedData(y)

# %% [markdown]
# ## Chichocki-Unbehauen Algorithm Feedback network

# %%
for i, y in enumerate(yFeedback):
    graph_fittedData(y)

# %% [markdown]
# ## Chichocki-Unbehauen Algorithm Feedforward network

# %%
for i, y in enumerate(yFeedforward):
    graph_fittedData(y)

# %% [markdown]
# # Fontes conhecidas

# %%
filePathSource = 'https://raw.githubusercontent.com/micaelverissimo/ICA/master/Mixture_keys/FourthSource1000Stats.txt'
distDataFrameSources = pd.read_table(filePathSource, delimiter = '\s+', header = None)
mixtures = distDataFrame.values
print(distDataFrame.shape)
distDataFrame.T.head()
# Out:
# (5, 1000)
#           0         1         2          3         4
# 0 -4.632472 -0.212518  2.338407   0.831017 -6.417481
# 1 -7.526377 -7.222836  5.739285  11.365812 -3.120320
# 2  2.906268 -1.592086  1.012788   5.034538  2.623468
# 3  0.058220 -2.802066  1.920736   5.696890  1.383289
# 4 -0.556034 -2.844038  2.688410   6.780288 -2.209821

# %%
scatter_matrix(distDataFrameSources.T, alpha=0.4, diagonal = 'kde', figsize = (10,10))
plt.show()

# %% [markdown]
# ## NPCA-RLS

# %%
from evaluation import KLmatrix, MImatrix
KLmatrix(distDataFrameSources.values,yNPCA)
MImatrix(distDataFrameSources.values,yNPCA)
# Out:
# (5, 1000) (5, 1000)
# [[ 1.37682962  0.71835802  1.10142521  0.59239692  0.48807835]
#  [ 0.48699232  0.44883977  0.53844491  0.42677381  0.35906311]
#  [ 2.00011199  0.06024173  0.16770267  0.07350984  0.08905863]
#  [ 2.30751885  0.28177988  0.41633446  0.24350743  0.31468023]
#  [ 0.35002024  2.04690498  1.9186929   1.9469447   1.81326877]]

# %% [markdown]
# ## Chichocki-Unbehauen Algorithm Feedback network

# %%
KLmatrix(distDataFrameSources.values,yFeedback)
MImatrix(distDataFrameSources.values,yFeedback)
# Out:
# (5, 1000) (5, 1000)
# [[ 1.27895086  0.70584545  1.04501345  0.74408926  0.44647596]
#  [ 0.40456412  0.46202875  0.46777093  0.34494937  0.29608224]
#  [ 1.76852287  0.06139705  0.46902947  0.09238389  0.11508519]
#  [ 2.14781915  0.26300039  0.45708226  0.2820315   0.31366207]
#  [ 0.35263406  2.06390989  1.71880363  1.78153398  1.55106952]]

# %% [markdown]
# ## Chichocki-Unbehauen Algorithm Feedforward network

# %%
KLmatrix(distDataFrameSources.values,yFeedforward)
MImatrix(distDataFrameSources.values,yFeedforward)
# Out:
# (5, 1000) (5, 1000)
# [[ 1.33223894  0.76461214  1.03145524  0.66310121  0.43864258]
#  [ 0.57700165  0.35891756  0.28721991  0.37941433  0.27875791]
#  [ 3.14682294  0.07793134  0.37023197  0.06544848  0.11906545]
#  [ 3.14078706  0.26179132  0.43011533  0.23548854  0.32301986]
#  [ 0.20091517  1.89052031  1.59444681  1.78647227  1.52350319]]
