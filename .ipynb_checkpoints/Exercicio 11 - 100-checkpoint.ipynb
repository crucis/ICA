# %% [markdown]
# # Exercício 11 de Análise de Componentes Independentes
# Pedro Bandeira de Mello Martins
#
# CPE 782 - Análise de Componentes Independentes
#
#
#
# Análise feita para 100 amostras

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.linalg import inv
from scipy.cluster.vq import whiten
import pandas as pd
from pandas.plotting import scatter_matrix
from scipy.stats import entropy, chi2_contingency, shapiro

# %matplotlib inline
from evaluation import calculateNegentropy, kde_entropy, KLdivergence, resultsTable, plot_MutualInformation
from ICAfunctions import cichocki_Feedback, cichocki_Feedforward, NPCA_RLS

#Notes:
#SHAPIRO: The algorithm used is described in [R634] but censoring parameters as 
#        described are not implemented. For N > 5000 the W test statistic is 
#        accurate but the p-value may not be.

# %%
learning_rate = 1e-6
gaussian_distribution = np.random.normal(0,1,1000)
shapiro(np.random.uniform(-1,1,1000))
# Out:
# (0.9499887824058533, 6.323249430173305e-18)

# %%
filePath = 'https://raw.githubusercontent.com/micaelverissimo/ICA/master/EleventhMixture100Stats.txt'
distDataFrame = pd.read_table(filePath, delimiter = '\s+', header = None)
mixtures = distDataFrame.values
print(distDataFrame.T.head())
# Out:
#           0          1          2          3
# 0 -7.149059  -9.344606  -4.117022  -8.224280
# 1 -5.409809  -7.095397  -2.626432  -5.661276
# 2 -8.583704 -11.791890 -10.000964 -13.290034
# 3 -3.419222  -3.833004  -1.314751  -2.438817
# 4 -7.175127  -8.783212  -4.867490  -9.896496

# %%
scatter_matrix(distDataFrame.T, alpha=0.4, diagonal = 'kde', figsize = (10,10))
plt.show()

# %%
resultsTable(mixtures)
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  Data</th><th style="text-align: right;">  Negentropy</th><th style="text-align: right;">  KL Divergence</th><th style="text-align: right;">  Shapiro-Wilk test W</th><th style="text-align: right;">  Shapiro-Wilk test P_value</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     0</td><td style="text-align: right;">      0.0192</td><td style="text-align: right;">         0.307 </td><td style="text-align: right;">               0.991 </td><td style="text-align: right;">                   0.74295 </td></tr>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;">      0     </td><td style="text-align: right;">         0.369 </td><td style="text-align: right;">               0.9844</td><td style="text-align: right;">                   0.28592 </td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;">      0.1204</td><td style="text-align: right;">         0.1569</td><td style="text-align: right;">               0.9713</td><td style="text-align: right;">                   0.027651</td></tr>
# <tr><td style="text-align: right;">     3</td><td style="text-align: right;">      0.1465</td><td style="text-align: right;">         0.4504</td><td style="text-align: right;">               0.9887</td><td style="text-align: right;">                   0.563   </td></tr>
# </tbody>
# </table>

# %% [markdown]
# ## NPCA-RLS Algorithm

# %%
[yNPCA, WNPCA] = NPCA_RLS(mixtures,runs = 1)
# Out:
# Execution time: 0.03000354766845703 seconds

# %%
scatter_matrix(pd.DataFrame(yNPCA.T), alpha = 0.4, diagonal = 'kde', figsize = (10,10))
plt.show()

# %%
resultsTable(yNPCA)
plot_MutualInformation(mixtures, y = yNPCA, KDE = True)
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  Data</th><th style="text-align: right;">  Negentropy</th><th style="text-align: right;">  KL Divergence</th><th style="text-align: right;">  Shapiro-Wilk test W</th><th style="text-align: right;">  Shapiro-Wilk test P_value</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     0</td><td style="text-align: right;">      0.1659</td><td style="text-align: right;">         0.1918</td><td style="text-align: right;">               0.983 </td><td style="text-align: right;">                    0.22628</td></tr>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;">      0.2112</td><td style="text-align: right;">         0.0651</td><td style="text-align: right;">               0.9864</td><td style="text-align: right;">                    0.40002</td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;">      0.3324</td><td style="text-align: right;">         0.0855</td><td style="text-align: right;">               0.9791</td><td style="text-align: right;">                    0.11403</td></tr>
# <tr><td style="text-align: right;">     3</td><td style="text-align: right;">      0     </td><td style="text-align: right;">         0.2328</td><td style="text-align: right;">               0.9847</td><td style="text-align: right;">                    0.30448</td></tr>
# </tbody>
# </table>

# %% [markdown]
# ## Chichocki-Unbehauen Algorithm Feedback network

# %%
[yFeedback, WFeedback] = cichocki_Feedback(mixtures, learningRate = 1e-5, decayRate = 1e-5, runs  = 1)
# Out:
# Execution time: 0.012000083923339844 seconds

# %%
scatter_matrix(pd.DataFrame(yFeedback.T), alpha = 0.4, diagonal = 'kde', figsize = (10,10))
plt.show()

# %%
resultsTable(yFeedback)
plot_MutualInformation(mixtures, y = yFeedback, KDE = True)
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  Data</th><th style="text-align: right;">  Negentropy</th><th style="text-align: right;">  KL Divergence</th><th style="text-align: right;">  Shapiro-Wilk test W</th><th style="text-align: right;">  Shapiro-Wilk test P_value</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     0</td><td style="text-align: right;">      0.0615</td><td style="text-align: right;">         2.8328</td><td style="text-align: right;">               0.9819</td><td style="text-align: right;">                   0.18764 </td></tr>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;">      0.083 </td><td style="text-align: right;">         0.0664</td><td style="text-align: right;">               0.9873</td><td style="text-align: right;">                   0.45752 </td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;">      0.1761</td><td style="text-align: right;">         0.1448</td><td style="text-align: right;">               0.9762</td><td style="text-align: right;">                   0.066523</td></tr>
# <tr><td style="text-align: right;">     3</td><td style="text-align: right;">      0.0645</td><td style="text-align: right;">         0.1727</td><td style="text-align: right;">               0.9813</td><td style="text-align: right;">                   0.16749 </td></tr>
# </tbody>
# </table>

# %% [markdown]
# ## Chichocki-Unbehauen Algorithm Feedforward network

# %%
[yFeedforward, WFeedforward] = cichocki_Feedforward(mixtures, learningRate = 1e-6, runs = 1)
# Out:
# Execution time: 0.03200268745422363 seconds

# %%
scatter_matrix(pd.DataFrame(yFeedforward.T), alpha = 0.4, diagonal = 'kde', figsize = (10,10))
plt.show()

# %%
resultsTable(yFeedforward)
plot_MutualInformation(mixtures, y = yFeedforward, KDE = True)
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  Data</th><th style="text-align: right;">  Negentropy</th><th style="text-align: right;">  KL Divergence</th><th style="text-align: right;">  Shapiro-Wilk test W</th><th style="text-align: right;">  Shapiro-Wilk test P_value</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     0</td><td style="text-align: right;">      0.0963</td><td style="text-align: right;">         0.2911</td><td style="text-align: right;">               0.9819</td><td style="text-align: right;">                   0.1879  </td></tr>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;">      0.1839</td><td style="text-align: right;">         0.1011</td><td style="text-align: right;">               0.9873</td><td style="text-align: right;">                   0.45786 </td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;">      0.178 </td><td style="text-align: right;">         0.7713</td><td style="text-align: right;">               0.9762</td><td style="text-align: right;">                   0.066634</td></tr>
# <tr><td style="text-align: right;">     3</td><td style="text-align: right;">      0     </td><td style="text-align: right;">         0.2502</td><td style="text-align: right;">               0.9813</td><td style="text-align: right;">                   0.1676  </td></tr>
# </tbody>
# </table>
