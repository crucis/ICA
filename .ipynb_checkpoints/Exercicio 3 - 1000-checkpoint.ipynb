# %% [markdown]
# # Exercício 3 de Análise de Componentes Independentes
# Pedro Bandeira de Mello Martins
#
# CPE 782 - Análise de Componentes Independentes
#
#
#
# Análise feita para 1000 amostras

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.linalg import inv
from scipy.cluster.vq import whiten
import pandas as pd
from pandas.plotting import scatter_matrix
from scipy.stats import entropy, chi2_contingency, shapiro

# %matplotlib inline
from evaluation import calculateNegentropy, kde_entropy, KLdivergence, resultsTable, plot_MutualInformation, graph_fittedData
from ICAfunctions import cichocki_Feedback, cichocki_Feedforward, NPCA_RLS

#Notes:
#SHAPIRO: The algorithm used is described in [R634] but censoring parameters as 
#        described are not implemented. For N > 5000 the W test statistic is 
#        accurate but the p-value may not be.

# %%
learning_rate = 1e-6
gaussian_distribution = np.random.normal(0,1,1000)
shapiro(np.random.uniform(-1,1,1000))
# Out:
# (0.9499604105949402, 6.246777823313697e-18)

# %%
filePath = 'https://raw.githubusercontent.com/micaelverissimo/ICA/master/ThirdMixture1000Stats.txt'
distDataFrame = pd.read_table(filePath, delimiter = '\s+', header = None)
mixtures = distDataFrame.values
print(distDataFrame.T.head())
# Out:
#           0         1         2
# 0 -1.796362 -1.394586 -1.830408
# 1 -2.815685 -1.192235 -2.516972
# 2  0.945715 -1.095434 -0.692399
# 3  0.556525  1.018854 -1.100344
# 4 -0.652160 -0.366929 -1.249465

# %%
scatter_matrix(distDataFrame.T, alpha=0.4, diagonal = 'kde', figsize = (10,10))
plt.show()

# %%
resultsTable(mixtures)
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  Data</th><th style="text-align: right;">  Negentropy</th><th style="text-align: right;">  KL Divergence</th><th style="text-align: right;">  Shapiro-Wilk test W</th><th style="text-align: right;">  Shapiro-Wilk test P_value</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     0</td><td style="text-align: right;">           0</td><td style="text-align: right;">         0.0202</td><td style="text-align: right;">               0.9978</td><td style="text-align: right;">                 0.1942    </td></tr>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;">           0</td><td style="text-align: right;">         0.3013</td><td style="text-align: right;">               0.97  </td><td style="text-align: right;">                 1.6069e-13</td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;">           0</td><td style="text-align: right;">         0.0234</td><td style="text-align: right;">               0.9972</td><td style="text-align: right;">                 0.080159  </td></tr>
# </tbody>
# </table>

# %% [markdown]
# ## NPCA-RLS Algorithm

# %%
[yNPCA, WNPCA] = NPCA_RLS(mixtures, runs = 1)
# Out:
# Execution time: 0.10651230812072754 seconds

# %%
scatter_matrix(pd.DataFrame(yNPCA.T), alpha = 0.4, diagonal = 'kde', figsize = (10,10))
plt.show()

# %%
resultsTable(yNPCA)
plot_MutualInformation(mixtures, y = yNPCA, KDE = True)
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  Data</th><th style="text-align: right;">  Negentropy</th><th style="text-align: right;">  KL Divergence</th><th style="text-align: right;">  Shapiro-Wilk test W</th><th style="text-align: right;">  Shapiro-Wilk test P_value</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     0</td><td style="text-align: right;">      0.0006</td><td style="text-align: right;">         0.0196</td><td style="text-align: right;">               0.9984</td><td style="text-align: right;">                 0.46454   </td></tr>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;">      0     </td><td style="text-align: right;">         0.0737</td><td style="text-align: right;">               0.9929</td><td style="text-align: right;">                 0.00010861</td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;">      0     </td><td style="text-align: right;">         0.4324</td><td style="text-align: right;">               0.967 </td><td style="text-align: right;">                 2.7944e-14</td></tr>
# </tbody>
# </table>

# %% [markdown]
# ## Chichocki-Unbehauen Algorithm Feedback network

# %%
[yFeedback, WFeedback] = cichocki_Feedback(mixtures, runs  = 1)
# Out:
# Execution time: 0.118011474609375 seconds

# %%
scatter_matrix(pd.DataFrame(yFeedback.T), alpha = 0.4, diagonal = 'kde', figsize = (10,10))
plt.show()

# %%
resultsTable(yFeedback)
plot_MutualInformation(mixtures, y = yFeedback, KDE = True)
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  Data</th><th style="text-align: right;">  Negentropy</th><th style="text-align: right;">  KL Divergence</th><th style="text-align: right;">  Shapiro-Wilk test W</th><th style="text-align: right;">  Shapiro-Wilk test P_value</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     0</td><td style="text-align: right;">           0</td><td style="text-align: right;">         0.0587</td><td style="text-align: right;">               0.9962</td><td style="text-align: right;">                 0.014124  </td></tr>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;">           0</td><td style="text-align: right;">         0.064 </td><td style="text-align: right;">               0.9967</td><td style="text-align: right;">                 0.034364  </td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;">           0</td><td style="text-align: right;">         0.3088</td><td style="text-align: right;">               0.9715</td><td style="text-align: right;">                 4.3035e-13</td></tr>
# </tbody>
# </table>

# %% [markdown]
# ## Chichocki-Unbehauen Algorithm Feedforward network

# %%
[yFeedforward, WFeedforward] = cichocki_Feedforward(mixtures, learningRate = 1e-9, runs = 1)
# Out:
# Execution time: 0.08800983428955078 seconds

# %%
scatter_matrix(pd.DataFrame(yFeedforward.T), alpha = 0.4, diagonal = 'kde', figsize = (10,10))
plt.show()

# %%
resultsTable(yFeedforward)
plot_MutualInformation(mixtures, y = yFeedforward, KDE = True)
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  Data</th><th style="text-align: right;">  Negentropy</th><th style="text-align: right;">  KL Divergence</th><th style="text-align: right;">  Shapiro-Wilk test W</th><th style="text-align: right;">  Shapiro-Wilk test P_value</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     0</td><td style="text-align: right;">           0</td><td style="text-align: right;">         0.0841</td><td style="text-align: right;">               0.9964</td><td style="text-align: right;">                 0.020749  </td></tr>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;">           0</td><td style="text-align: right;">         0.0524</td><td style="text-align: right;">               0.9972</td><td style="text-align: right;">                 0.085032  </td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;">           0</td><td style="text-align: right;">         2.6441</td><td style="text-align: right;">               0.975 </td><td style="text-align: right;">                 4.3908e-12</td></tr>
# </tbody>
# </table>

# %% [markdown]
# # Hipóteses de PDF

# %% [markdown]
# Aqui o objetivo é encontrar PDFs que representem as fontes encontradas. Utiliza-se uma função que testa todas as funções de densidade probabilística implementadas no pacote SciPy em Python e verifica qual das hipóteses tem o menor $\chi ^2$.

# %% [markdown]
# ## NPCA-RLS Algorithm

# %%
graph_fittedData(yNPCA[0])
graph_fittedData(yNPCA[1])
graph_fittedData(yNPCA[2])

# %% [markdown]
# ## Chichocki-Unbehauen Algorithm Feedback network

# %%
graph_fittedData(yFeedback[0])
graph_fittedData(yFeedback[1])
graph_fittedData(yFeedback[2])

# %% [markdown]
# ## Chichocki-Unbehauen Algorithm Feedforward network

# %%
graph_fittedData(yFeedforward[0])
graph_fittedData(yFeedforward[1])
graph_fittedData(yFeedforward[2])

# %% [markdown]
# # Fontes conhecidas

# %%
filePathSource = 'https://raw.githubusercontent.com/micaelverissimo/ICA/master/Mixture_keys/ThirdSource1000Stats.txt'
distDataFrameSources = pd.read_table(filePathSource, delimiter = '\s+', header = None)
mixtures = distDataFrame.values
print(distDataFrame.shape)
distDataFrame.T.head()
# Out:
# (3, 1000)
#           0         1         2
# 0 -1.796362 -1.394586 -1.830408
# 1 -2.815685 -1.192235 -2.516972
# 2  0.945715 -1.095434 -0.692399
# 3  0.556525  1.018854 -1.100344
# 4 -0.652160 -0.366929 -1.249465

# %%
scatter_matrix(distDataFrameSources.T, alpha=0.4, diagonal = 'kde', figsize = (10,10))
plt.show()

# %% [markdown]
# ## NPCA-RLS

# %%
from evaluation import KLmatrix, MImatrix
KLmatrix(distDataFrameSources.values,yNPCA)
MImatrix(distDataFrameSources.values,yNPCA)
# Out:
# (3, 1000) (3, 1000)
# [[ 0.68602704  0.33404429  0.61131875]
#  [ 0.7992232   0.39294086  0.01275805]
#  [ 0.02564002  0.07554612  0.50396973]]
# C:\Users\Pedro\Anaconda3\lib\site-packages\statsmodels\sandbox\distributions\mv_measures.py:47: RuntimeWarning: invalid value encountered in sqrt
#   mi_normed = np.sqrt(1. - np.exp(-2 * mi))

# %% [markdown]
# ## Chichocki-Unbehauen Algorithm Feedback network

# %%
KLmatrix(distDataFrameSources.values,yFeedback)
MImatrix(distDataFrameSources.values,yFeedback)
# Out:
# (3, 1000) (3, 1000)
# [[ 0.54239161  0.43574089  0.53398162]
#  [ 0.65686648  0.5439492   0.04505542]
#  [ 0.03242108  0.04614765  0.39915989]]

# %% [markdown]
# ## Chichocki-Unbehauen Algorithm Feedforward network

# %%
KLmatrix(distDataFrameSources.values,yFeedforward)
MImatrix(distDataFrameSources.values,yFeedforward)
# Out:
# (3, 1000) (3, 1000)
# [[ 0.57017229  0.41600437  0.5061604 ]
#  [ 0.59303155  0.52330497  0.08049322]
#  [ 0.03362771  0.04163582  0.34176174]]
