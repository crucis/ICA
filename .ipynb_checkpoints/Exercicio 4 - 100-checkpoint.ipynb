# %% [markdown]
# # Exercício 4 de Análise de Componentes Independentes
# Pedro Bandeira de Mello Martins
#
# CPE 782 - Análise de Componentes Independentes
#
#
#
# Análise feita para 100 amostras

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.linalg import inv
from scipy.cluster.vq import whiten
import pandas as pd
from pandas.plotting import scatter_matrix
from scipy.stats import entropy, chi2_contingency, shapiro

# %matplotlib inline
from evaluation import calculateNegentropy, kde_entropy, KLdivergence, resultsTable, plot_MutualInformation
from ICAfunctions import cichocki_Feedback, cichocki_Feedforward, NPCA_RLS

#Notes:
#SHAPIRO: The algorithm used is described in [R634] but censoring parameters as 
#        described are not implemented. For N > 5000 the W test statistic is 
#        accurate but the p-value may not be.

# %%
learning_rate = 1e-6
gaussian_distribution = np.random.normal(0,1,1000)
shapiro(np.random.uniform(-1,1,1000))
# Out:
# (0.9579463601112366, 2.375309347694613e-16)

# %%
filePath = 'https://raw.githubusercontent.com/micaelverissimo/ICA/master/FourthMixture100Stats.txt'
distDataFrame = pd.read_table(filePath, delimiter = '\s+', header = None)
mixtures = distDataFrame.values
print(distDataFrame.T.head())
# Out:
#           0         1         2         3         4
# 0  4.201776 -0.140798  1.172178  4.231279  0.333645
# 1 -4.061709 -0.094902  1.970187  0.362464 -3.079086
# 2 -3.397734 -4.395140  3.053519  6.914699 -0.751136
# 3 -2.350314 -1.235338  0.663581  1.348701 -1.406679
# 4 -4.926728 -1.361529  2.158155  1.883070 -3.976572

# %%
scatter_matrix(distDataFrame.T, alpha=0.4, diagonal = 'kde', figsize = (10,10))
plt.show()

# %%
resultsTable(mixtures)
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  Data</th><th style="text-align: right;">  Negentropy</th><th style="text-align: right;">  KL Divergence</th><th style="text-align: right;">  Shapiro-Wilk test W</th><th style="text-align: right;">  Shapiro-Wilk test P_value</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     0</td><td style="text-align: right;">      0.2335</td><td style="text-align: right;">        11.8043</td><td style="text-align: right;">               0.9481</td><td style="text-align: right;">                 0.00062633</td></tr>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;">      0.261 </td><td style="text-align: right;">         1.1834</td><td style="text-align: right;">               0.8715</td><td style="text-align: right;">                 8.0442e-08</td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;">      0.1932</td><td style="text-align: right;">         1.6748</td><td style="text-align: right;">               0.8698</td><td style="text-align: right;">                 6.9066e-08</td></tr>
# <tr><td style="text-align: right;">     3</td><td style="text-align: right;">      0.261 </td><td style="text-align: right;">         0.4952</td><td style="text-align: right;">               0.9227</td><td style="text-align: right;">                 1.9649e-05</td></tr>
# <tr><td style="text-align: right;">     4</td><td style="text-align: right;">      0.0595</td><td style="text-align: right;">         0.3194</td><td style="text-align: right;">               0.9761</td><td style="text-align: right;">                 0.065808  </td></tr>
# </tbody>
# </table>

# %% [markdown]
# ## NPCA-RLS Algorithm

# %%
[yNPCA, WNPCA] = NPCA_RLS(mixtures, runs = 1)
# Out:
# Execution time: 0.027002334594726562 seconds

# %%
scatter_matrix(pd.DataFrame(yNPCA.T), alpha = 0.4, diagonal = 'kde', figsize = (10,10))
plt.show()

# %%
resultsTable(yNPCA)
plot_MutualInformation(mixtures, y = yNPCA, KDE = True)
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  Data</th><th style="text-align: right;">  Negentropy</th><th style="text-align: right;">  KL Divergence</th><th style="text-align: right;">  Shapiro-Wilk test W</th><th style="text-align: right;">  Shapiro-Wilk test P_value</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     0</td><td style="text-align: right;">      0.3381</td><td style="text-align: right;">         0.8781</td><td style="text-align: right;">               0.8508</td><td style="text-align: right;">                 1.2693e-08</td></tr>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;">      0     </td><td style="text-align: right;">         0.1976</td><td style="text-align: right;">               0.9908</td><td style="text-align: right;">                 0.73124   </td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;">      0     </td><td style="text-align: right;">         0.1483</td><td style="text-align: right;">               0.9865</td><td style="text-align: right;">                 0.40481   </td></tr>
# <tr><td style="text-align: right;">     3</td><td style="text-align: right;">      0.3618</td><td style="text-align: right;">         0.9527</td><td style="text-align: right;">               0.955 </td><td style="text-align: right;">                 0.0017944 </td></tr>
# <tr><td style="text-align: right;">     4</td><td style="text-align: right;">      0.0141</td><td style="text-align: right;">         5.9484</td><td style="text-align: right;">               0.9941</td><td style="text-align: right;">                 0.94601   </td></tr>
# </tbody>
# </table>

# %% [markdown]
# ## Chichocki-Unbehauen Algorithm Feedback network

# %%
[yFeedback, WFeedback] = cichocki_Feedback(mixtures, runs  = 1)
# Out:
# Execution time: 0.017502307891845703 seconds

# %%
scatter_matrix(pd.DataFrame(yFeedback.T), alpha = 0.4, diagonal = 'kde', figsize = (10,10))
plt.show()

# %%
resultsTable(yFeedback)
plot_MutualInformation(mixtures, y = yFeedback, KDE = True)
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  Data</th><th style="text-align: right;">  Negentropy</th><th style="text-align: right;">  KL Divergence</th><th style="text-align: right;">  Shapiro-Wilk test W</th><th style="text-align: right;">  Shapiro-Wilk test P_value</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     0</td><td style="text-align: right;">      0.3795</td><td style="text-align: right;">         1.2426</td><td style="text-align: right;">               0.8523</td><td style="text-align: right;">                 1.4422e-08</td></tr>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;">      0.1339</td><td style="text-align: right;">         0.0352</td><td style="text-align: right;">               0.9891</td><td style="text-align: right;">                 0.59235   </td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;">      0     </td><td style="text-align: right;">         0.186 </td><td style="text-align: right;">               0.9906</td><td style="text-align: right;">                 0.70912   </td></tr>
# <tr><td style="text-align: right;">     3</td><td style="text-align: right;">      0.2787</td><td style="text-align: right;">         0.3406</td><td style="text-align: right;">               0.9693</td><td style="text-align: right;">                 0.019383  </td></tr>
# <tr><td style="text-align: right;">     4</td><td style="text-align: right;">      0     </td><td style="text-align: right;">         0.1465</td><td style="text-align: right;">               0.9905</td><td style="text-align: right;">                 0.7011    </td></tr>
# </tbody>
# </table>

# %% [markdown]
# ## Chichocki-Unbehauen Algorithm Feedforward network

# %%
[yFeedforward, WFeedforward] = cichocki_Feedforward(mixtures, learningRate = 1e-6, runs = 1)
# Out:
# Execution time: 0.012501716613769531 seconds

# %%
scatter_matrix(pd.DataFrame(yFeedforward.T), alpha = 0.4, diagonal = 'kde', figsize = (10,10))
plt.show()

# %%
resultsTable(yFeedforward)
plot_MutualInformation(mixtures, y = yFeedforward, KDE = True)
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  Data</th><th style="text-align: right;">  Negentropy</th><th style="text-align: right;">  KL Divergence</th><th style="text-align: right;">  Shapiro-Wilk test W</th><th style="text-align: right;">  Shapiro-Wilk test P_value</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     0</td><td style="text-align: right;">      0.4253</td><td style="text-align: right;">         0.8937</td><td style="text-align: right;">               0.8652</td><td style="text-align: right;">                 4.4932e-08</td></tr>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;">      0     </td><td style="text-align: right;">         0.1189</td><td style="text-align: right;">               0.9891</td><td style="text-align: right;">                 0.59373   </td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;">      0.1077</td><td style="text-align: right;">         3.8095</td><td style="text-align: right;">               0.9899</td><td style="text-align: right;">                 0.6591    </td></tr>
# <tr><td style="text-align: right;">     3</td><td style="text-align: right;">      0.3409</td><td style="text-align: right;">         0.5843</td><td style="text-align: right;">               0.9664</td><td style="text-align: right;">                 0.011717  </td></tr>
# <tr><td style="text-align: right;">     4</td><td style="text-align: right;">      0.0729</td><td style="text-align: right;">         0.2147</td><td style="text-align: right;">               0.9916</td><td style="text-align: right;">                 0.7882    </td></tr>
# </tbody>
# </table>
