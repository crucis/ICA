# %% [markdown]
# # Exercício 8 de Análise de Componentes Independentes
# Pedro Bandeira de Mello Martins
#
# CPE 782 - Análise de Componentes Independentes
#
#
#
# Análise feita para 100000 amostras

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.linalg import inv
from scipy.cluster.vq import whiten
import pandas as pd
from pandas.plotting import scatter_matrix
from scipy.stats import entropy, chi2_contingency, shapiro

# %matplotlib inline
from evaluation import calculateNegentropy, kde_entropy, KLdivergence, resultsTable, plot_MutualInformation
from ICAfunctions import cichocki_Feedback, cichocki_Feedforward, NPCA_RLS

#Notes:
#SHAPIRO: The algorithm used is described in [R634] but censoring parameters as 
#        described are not implemented. For N > 5000 the W test statistic is 
#        accurate but the p-value may not be.

# %%
learning_rate = 1e-6
gaussian_distribution = np.random.normal(0,1,1000)
shapiro(np.random.uniform(-1,1,1000))
# Out:
# (0.9549812078475952, 5.834571390201984e-17)

# %%
filePath = 'https://raw.githubusercontent.com/micaelverissimo/ICA/master/EighthMixture100000Stats.txt'
distDataFrame = pd.read_table(filePath, delimiter = '\s+', header = None)
mixtures = distDataFrame.values
print(distDataFrame.T.head())
# Out:
#           0          1         2         3          4
# 0  0.931529   1.467969  0.559879  2.266547   1.638147
# 1  0.203738  41.584692  1.536816  1.793232  11.560561
# 2  5.801349   7.772373  1.553867  0.270714   2.628631
# 3  0.208559  14.767518  0.463100  0.936650   1.998944
# 4  0.390824  57.080635  0.065783  1.176220  20.980384

# %%
scatter_matrix(distDataFrame.T, alpha=0.4, diagonal = 'kde', figsize = (10,10))
plt.show()

# %%
resultsTable(mixtures, negentropyType = 'KDE', n_bins = 100)
# Out:
# C:\Users\Pedro\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1326: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# C:\Users\Pedro\Anaconda3\lib\site-packages\scipy\integrate\quadpack.py:364: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   warnings.warn(msg, IntegrationWarning)
# <table>
# <thead>
# <tr><th style="text-align: right;">  Data</th><th style="text-align: right;">  Negentropy</th><th style="text-align: right;">  KL Divergence</th><th style="text-align: right;">  Shapiro-Wilk test W</th><th style="text-align: right;">  Shapiro-Wilk test P_value</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     0</td><td style="text-align: right;">      0.4734</td><td style="text-align: right;">         5.4305</td><td style="text-align: right;">               0.8137</td><td style="text-align: right;">                          0</td></tr>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;">     16.8286</td><td style="text-align: right;">        11.5126</td><td style="text-align: right;">               0.0005</td><td style="text-align: right;">                          0</td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;">      0.7428</td><td style="text-align: right;">        43.1504</td><td style="text-align: right;">               0.5733</td><td style="text-align: right;">                          0</td></tr>
# <tr><td style="text-align: right;">     3</td><td style="text-align: right;">      4.4678</td><td style="text-align: right;">        11.4953</td><td style="text-align: right;">               0.0114</td><td style="text-align: right;">                          0</td></tr>
# <tr><td style="text-align: right;">     4</td><td style="text-align: right;">      0.6323</td><td style="text-align: right;">         9.3501</td><td style="text-align: right;">               0.6251</td><td style="text-align: right;">                          0</td></tr>
# </tbody>
# </table>

# %% [markdown]
# ## NPCA-RLS Algorithm

# %%
[yNPCA, WNPCA] = NPCA_RLS(mixtures, beta = 0.999999991, decay = False, decayRate = 1e-8, runs = 1)
# Out:
# Execution time: 7.2520270347595215 seconds

# %%
scatter_matrix(pd.DataFrame(yNPCA.T), alpha = 0.4, diagonal = 'kde', figsize = (10,10))
plt.show()

# %%
resultsTable(yNPCA)
#plot_MutualInformation(mixtures[-1000:], y = yNPCA[-1000:], KDE = True)
# Out:
# C:\Users\Pedro\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1326: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# <table>
# <thead>
# <tr><th style="text-align: right;">  Data</th><th style="text-align: right;">  Negentropy</th><th style="text-align: right;">  KL Divergence</th><th style="text-align: right;">  Shapiro-Wilk test W</th><th style="text-align: right;">  Shapiro-Wilk test P_value</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     0</td><td style="text-align: right;">      3.3135</td><td style="text-align: right;">       100.407 </td><td style="text-align: right;">               0.5528</td><td style="text-align: right;">                          0</td></tr>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;">      3.3508</td><td style="text-align: right;">         7.9928</td><td style="text-align: right;">               0.4858</td><td style="text-align: right;">                          0</td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;">      3.323 </td><td style="text-align: right;">         7.1307</td><td style="text-align: right;">               0.5379</td><td style="text-align: right;">                          0</td></tr>
# <tr><td style="text-align: right;">     3</td><td style="text-align: right;">      3.4905</td><td style="text-align: right;">         8.2942</td><td style="text-align: right;">               0.5399</td><td style="text-align: right;">                          0</td></tr>
# <tr><td style="text-align: right;">     4</td><td style="text-align: right;">      2.8849</td><td style="text-align: right;">        99.8824</td><td style="text-align: right;">               0.7754</td><td style="text-align: right;">                          0</td></tr>
# </tbody>
# </table>

# %% [markdown]
# ## Chichocki-Unbehauen Algorithm Feedback network

# %%
[yFeedback, WFeedback] = cichocki_Feedback(mixtures, runs  = 1)
# Out:
# Execution time: 9.728657722473145 seconds

# %%
scatter_matrix(pd.DataFrame(yFeedback.T), alpha = 0.4, diagonal = 'kde', figsize = (10,10))
plt.show()

# %%
resultsTable(yFeedback)
#plot_MutualInformation(mixtures[-1000:], y = yFeedback[-1000:], KDE = False)
# Out:
# C:\Users\Pedro\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1326: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# <table>
# <thead>
# <tr><th style="text-align: right;">  Data</th><th style="text-align: right;">  Negentropy</th><th style="text-align: right;">  KL Divergence</th><th style="text-align: right;">  Shapiro-Wilk test W</th><th style="text-align: right;">  Shapiro-Wilk test P_value</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     0</td><td style="text-align: right;">      4.3391</td><td style="text-align: right;">        10.8202</td><td style="text-align: right;">               0.0005</td><td style="text-align: right;">                          0</td></tr>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;">      3.9635</td><td style="text-align: right;">       103.059 </td><td style="text-align: right;">               0.186 </td><td style="text-align: right;">                          0</td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;">      2.7777</td><td style="text-align: right;">        42.8223</td><td style="text-align: right;">               0.6075</td><td style="text-align: right;">                          0</td></tr>
# <tr><td style="text-align: right;">     3</td><td style="text-align: right;">      3.1963</td><td style="text-align: right;">         8.2447</td><td style="text-align: right;">               0.6744</td><td style="text-align: right;">                          0</td></tr>
# <tr><td style="text-align: right;">     4</td><td style="text-align: right;">      2.7163</td><td style="text-align: right;">         6.1846</td><td style="text-align: right;">               0.8081</td><td style="text-align: right;">                          0</td></tr>
# </tbody>
# </table>

# %% [markdown]
# ## Chichocki-Unbehauen Algorithm Feedforward network

# %%
[yFeedforward, WFeedforward] = cichocki_Feedforward(mixtures, learningRate = 1e-11, runs = 1)
# Out:
# Execution time: 6.980907917022705 seconds

# %%
scatter_matrix(pd.DataFrame(yFeedforward.T), alpha = 0.4, diagonal = 'kde', figsize = (10,10))
plt.show()

# %%
#resultsTable(yFeedforward)
#plot_MutualInformation(mixtures[-1000:], y = yFeedforward[-1000:], KDE = False)
# Out:
# C:\Users\Pedro\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1326: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-14-c15b75a1d77e> in <module>()
# ----> 1 resultsTable(yFeedforward)
#       2 #plot_MutualInformation(mixtures[-1000:], y = yFeedforward[-1000:], KDE = False)
#
# E:\OneDrive\Documentos\UFRJ\Mestrado\PEE\ICA\funcoes\evaluation.py in resultsTable(y, n_bins, negentropyType)
#     115         shapiro_yi = shapiro(y_i)
#     116         new_row = np.array([["%d"%i, "%.04f"%calculateNegentropy(y_i, n_bins = n_bins,
# --> 117                                                                  kindOfNegentropy = negentropyType),
#     118                              "%0.4f"%KLdivergence(y_i, n_bins = n_bins),
#     119                              "%.04f"%shapiro_yi[0], "%.04E"%shapiro_yi[1]]])
#
# E:\OneDrive\Documentos\UFRJ\Mestrado\PEE\ICA\funcoes\evaluation.py in calculateNegentropy(x, kindOfNegentropy, n_bins)
#      40             bins_gaussian = len(np.histogram(np.random.normal(loc=np.mean(x), scale=np.std(x),
#      41                                                               size = len(x)), bins = 'fd')[0])
# ---> 42             bins_x = len(np.histogram(x, bins = 'fd')[0])
#      43             n_bins = min(bins_gaussian, bins_x)
#      44         gaussian_hist = np.histogram(np.random.normal(loc=np.mean(x), scale=np.std(x),
#
# C:\Users\Pedro\Anaconda3\lib\site-packages\numpy\lib\function_base.py in histogram(a, bins, range, normed, weights, density)
#     726
#     727         # Initialize empty histogram
# --> 728         n = np.zeros(bins, ntype)
#     729         # Pre-compute histogram scaling factor
#     730         norm = bins / (mx - mn)
#
# MemoryError:

# %% [markdown]
# # Hipóteses de PDF

# %% [markdown]
# Aqui o objetivo é encontrar PDFs que representem as fontes encontradas. Utiliza-se uma função que testa todas as funções de densidade probabilística implementadas no pacote SciPy em Python e verifica qual das hipóteses tem o menor $\chi ^2$.

# %% [markdown]
# ## NPCA-RLS Algorithm

# %%
from evaluation import graph_fittedData
for i, y in enumerate(yNPCA):
    graph_fittedData(y)

# %% [markdown]
# ## Chichocki-Unbehauen Algorithm Feedback network

# %%
for i, y in enumerate(yFeedback):
    graph_fittedData(y)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\Pedro\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2881, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-16-d71c948aa7fd>", line 2, in <module>
#     graph_fittedData(y)
#   File "E:\OneDrive\Documentos\UFRJ\Mestrado\PEE\ICA\funcoes\evaluation.py", line 332, in graph_fittedData
#     plt.hist(data_to_be_fitted, bins = 'fd', normed=True)
#   File "C:\Users\Pedro\Anaconda3\lib\site-packages\matplotlib\pyplot.py", line 3081, in hist
#     stacked=stacked, data=data, **kwargs)
#   File "C:\Users\Pedro\Anaconda3\lib\site-packages\matplotlib\__init__.py", line 1897, in inner
#     return func(ax, *args, **kwargs)
#   File "C:\Users\Pedro\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py", line 6279, in hist
#     color=c, **{bottom_kwarg: bottom})
#   File "C:\Users\Pedro\Anaconda3\lib\site-packages\matplotlib\__init__.py", line 1897, in inner
#     return func(ax, *args, **kwargs)
#   File "C:\Users\Pedro\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py", line 2105, in bar
#     left = [left[i] - width[i] / 2. for i in xrange(len(left))]
#   File "C:\Users\Pedro\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py", line 2105, in <listcomp>
#     left = [left[i] - width[i] / 2. for i in xrange(len(left))]
# MemoryError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Pedro\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 1821, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'MemoryError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Pedro\Anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1132, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\Pedro\Anaconda3\lib\site-packages\IPython\core\ultratb.py", line 313, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\Pedro\Anaconda3\lib\site-packages\IPython\core\ultratb.py", line 358, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\Pedro\Anaconda3\lib\inspect.py", line 1453, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\Pedro\Anaconda3\lib\inspect.py", line 1411, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\Pedro\Anaconda3\lib\inspect.py", line 666, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\Pedro\Anaconda3\lib\inspect.py", line 705, in getmodule
#     if f == _filesbymodname.get(modname, None):
# KeyboardInterrupt
# ---------------------------------------------------------------------------

# %% [markdown]
# ## Chichocki-Unbehauen Algorithm Feedforward network

# %%
for i, y in enumerate(yFeedforward):
    graph_fittedData(y)
