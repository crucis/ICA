# %% [markdown]
# # Exercício 8 de Análise de Componentes Independentes
# Pedro Bandeira de Mello Martins
#
# CPE 782 - Análise de Componentes Independentes
#
#
#
# Análise feita para 100 amostras

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.linalg import inv
from scipy.cluster.vq import whiten
import pandas as pd
from pandas.plotting import scatter_matrix
from scipy.stats import entropy, chi2_contingency, shapiro

# %matplotlib inline
from evaluation import calculateNegentropy, kde_entropy, KLdivergence, resultsTable, plot_MutualInformation
from ICAfunctions import cichocki_Feedback, cichocki_Feedforward, NPCA_RLS

#Notes:
#SHAPIRO: The algorithm used is described in [R634] but censoring parameters as 
#        described are not implemented. For N > 5000 the W test statistic is 
#        accurate but the p-value may not be.

# %%
learning_rate = 1e-6
gaussian_distribution = np.random.normal(0,1,1000)
shapiro(np.random.uniform(-1,1,1000))
# Out:
# (0.9552580714225769, 6.633139494494558e-17)

# %%
filePath = 'https://raw.githubusercontent.com/micaelverissimo/ICA/master/EighthMixture100Stats.txt'
distDataFrame = pd.read_table(filePath, delimiter = '\s+', header = None)
mixtures = distDataFrame.values
print(distDataFrame.T.head())
# Out:
#           0              1         2          3         4
# 0  0.785424      12.777850  0.682670  13.435324  3.561111
# 1  0.842213  211467.214344  0.327126   1.918556  4.028181
# 2  0.185441       1.816125  0.298350   0.617460  1.095587
# 3  3.795056     354.440279  2.568090   0.822998  2.919371
# 4  2.175962       5.305139  0.395776   1.536879  3.468964

# %%
scatter_matrix(distDataFrame.T, alpha=0.4, diagonal = 'kde', figsize = (10,10))
plt.show()

# %%
resultsTable(mixtures)
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  Data</th><th style="text-align: right;">  Negentropy</th><th style="text-align: right;">  KL Divergence</th><th style="text-align: right;">  Shapiro-Wilk test W</th><th style="text-align: right;">  Shapiro-Wilk test P_value</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     0</td><td style="text-align: right;">      0.026 </td><td style="text-align: right;">         0.8178</td><td style="text-align: right;">               0.8537</td><td style="text-align: right;">                 1.6325e-08</td></tr>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;">      1.9554</td><td style="text-align: right;">         3.5209</td><td style="text-align: right;">               0.2337</td><td style="text-align: right;">                 1.782e-20 </td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;">      0.9178</td><td style="text-align: right;">         1.7709</td><td style="text-align: right;">               0.6739</td><td style="text-align: right;">                 1.3836e-13</td></tr>
# <tr><td style="text-align: right;">     3</td><td style="text-align: right;">      0.9321</td><td style="text-align: right;">         2.1865</td><td style="text-align: right;">               0.5574</td><td style="text-align: right;">                 7.1617e-16</td></tr>
# <tr><td style="text-align: right;">     4</td><td style="text-align: right;">      0.754 </td><td style="text-align: right;">         1.7224</td><td style="text-align: right;">               0.7522</td><td style="text-align: right;">                 1.0718e-11</td></tr>
# </tbody>
# </table>

# %% [markdown]
# ## NPCA-RLS Algorithm

# %%
[yNPCA, WNPCA] = NPCA_RLS(mixtures,runs = 1)
# Out:
# Execution time: 0.020000934600830078 seconds

# %%
scatter_matrix(pd.DataFrame(yNPCA.T), alpha = 0.4, diagonal = 'kde', figsize = (10,10))
plt.show()

# %%
resultsTable(yNPCA)
plot_MutualInformation(mixtures, y = yNPCA, KDE = True)
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  Data</th><th style="text-align: right;">  Negentropy</th><th style="text-align: right;">  KL Divergence</th><th style="text-align: right;">  Shapiro-Wilk test W</th><th style="text-align: right;">  Shapiro-Wilk test P_value</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     0</td><td style="text-align: right;">      0.9939</td><td style="text-align: right;">         2.0041</td><td style="text-align: right;">               0.5937</td><td style="text-align: right;">                 3.2741e-15</td></tr>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;">      0.3294</td><td style="text-align: right;">         0.6742</td><td style="text-align: right;">               0.8665</td><td style="text-align: right;">                 5.0981e-08</td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;">      0.1536</td><td style="text-align: right;">         0.6967</td><td style="text-align: right;">               0.9556</td><td style="text-align: right;">                 0.0019771 </td></tr>
# <tr><td style="text-align: right;">     3</td><td style="text-align: right;">      0.3929</td><td style="text-align: right;">         1.061 </td><td style="text-align: right;">               0.841 </td><td style="text-align: right;">                 5.5726e-09</td></tr>
# <tr><td style="text-align: right;">     4</td><td style="text-align: right;">      0.1833</td><td style="text-align: right;">         0.2557</td><td style="text-align: right;">               0.9707</td><td style="text-align: right;">                 0.024827  </td></tr>
# </tbody>
# </table>
# C:\Users\Pedro\Anaconda3\lib\site-packages\statsmodels\sandbox\distributions\mv_measures.py:47: RuntimeWarning: invalid value encountered in sqrt
#   mi_normed = np.sqrt(1. - np.exp(-2 * mi))

# %% [markdown]
# ## Chichocki-Unbehauen Algorithm Feedback network

# %%
[yFeedback, WFeedback] = cichocki_Feedback(mixtures, learningRate = 1e-3, decayRate = 1e-7, runs  = 1)
# Out:
# Execution time: 0.018001556396484375 seconds

# %%
scatter_matrix(pd.DataFrame(yFeedback.T), alpha = 0.4, diagonal = 'kde', figsize = (10,10))
plt.show()

# %%
resultsTable(yFeedback)
plot_MutualInformation(mixtures, y = yFeedback, KDE = True)
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  Data</th><th style="text-align: right;">  Negentropy</th><th style="text-align: right;">  KL Divergence</th><th style="text-align: right;">  Shapiro-Wilk test W</th><th style="text-align: right;">  Shapiro-Wilk test P_value</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     0</td><td style="text-align: right;">      1.7406</td><td style="text-align: right;">         2.8808</td><td style="text-align: right;">               0.2462</td><td style="text-align: right;">                 2.5023e-20</td></tr>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;">      0.421 </td><td style="text-align: right;">         1.3398</td><td style="text-align: right;">               0.784 </td><td style="text-align: right;">                 8.2285e-11</td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;">      0.441 </td><td style="text-align: right;">         0.5623</td><td style="text-align: right;">               0.8822</td><td style="text-align: right;">                 2.2503e-07</td></tr>
# <tr><td style="text-align: right;">     3</td><td style="text-align: right;">      0     </td><td style="text-align: right;">         0.6068</td><td style="text-align: right;">               0.8988</td><td style="text-align: right;">                 1.2482e-06</td></tr>
# <tr><td style="text-align: right;">     4</td><td style="text-align: right;">      0.3541</td><td style="text-align: right;">         0.0844</td><td style="text-align: right;">               0.9468</td><td style="text-align: right;">                 0.00051322</td></tr>
# </tbody>
# </table>
# C:\Users\Pedro\Anaconda3\lib\site-packages\statsmodels\sandbox\distributions\mv_measures.py:47: RuntimeWarning: invalid value encountered in sqrt
#   mi_normed = np.sqrt(1. - np.exp(-2 * mi))

# %% [markdown]
# ## Chichocki-Unbehauen Algorithm Feedforward network

# %%
[yFeedforward, WFeedforward] = cichocki_Feedforward(mixtures, learningRate = 1e-8, runs = 1)
# Out:
# Execution time: 0.012003183364868164 seconds

# %%
scatter_matrix(pd.DataFrame(yFeedforward.T), alpha = 0.4, diagonal = 'kde', figsize = (10,10))
plt.show()

# %%
resultsTable(yFeedforward)
plot_MutualInformation(mixtures, y = yFeedforward, KDE = True)
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  Data</th><th style="text-align: right;">  Negentropy</th><th style="text-align: right;">  KL Divergence</th><th style="text-align: right;">  Shapiro-Wilk test W</th><th style="text-align: right;">  Shapiro-Wilk test P_value</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     0</td><td style="text-align: right;">      1.6476</td><td style="text-align: right;">         3.5562</td><td style="text-align: right;">               0.2337</td><td style="text-align: right;">                 1.782e-20 </td></tr>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;">      0.6335</td><td style="text-align: right;">         1.3483</td><td style="text-align: right;">               0.7824</td><td style="text-align: right;">                 7.3948e-11</td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;">      0.2696</td><td style="text-align: right;">         0.8479</td><td style="text-align: right;">               0.8755</td><td style="text-align: right;">                 1.1741e-07</td></tr>
# <tr><td style="text-align: right;">     3</td><td style="text-align: right;">      0.0332</td><td style="text-align: right;">         0.4382</td><td style="text-align: right;">               0.8978</td><td style="text-align: right;">                 1.1167e-06</td></tr>
# <tr><td style="text-align: right;">     4</td><td style="text-align: right;">      0.2518</td><td style="text-align: right;">         0.4941</td><td style="text-align: right;">               0.9466</td><td style="text-align: right;">                 0.00049838</td></tr>
# </tbody>
# </table>
# C:\Users\Pedro\Anaconda3\lib\site-packages\statsmodels\sandbox\distributions\mv_measures.py:47: RuntimeWarning: invalid value encountered in sqrt
#   mi_normed = np.sqrt(1. - np.exp(-2 * mi))
