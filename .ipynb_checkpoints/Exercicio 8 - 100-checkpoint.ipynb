# %% [markdown]
# # Exercício 8 de Análise de Componentes Independentes
# Pedro Bandeira de Mello Martins
#
# CPE 782 - Análise de Componentes Independentes
#
#
#
# Análise feita para 100 amostras

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.linalg import inv
from scipy.cluster.vq import whiten
import pandas as pd
from pandas.plotting import scatter_matrix
from scipy.stats import entropy, chi2_contingency, shapiro

# %matplotlib inline
from evaluation import calculateNegentropy, kde_entropy, KLdivergence, resultsTable, plot_MutualInformation
from ICAfunctions import cichocki_Feedback, cichocki_Feedforward, NPCA_RLS

#Notes:
#SHAPIRO: The algorithm used is described in [R634] but censoring parameters as 
#        described are not implemented. For N > 5000 the W test statistic is 
#        accurate but the p-value may not be.

# %%
learning_rate = 1e-6
gaussian_distribution = np.random.normal(0,1,1000)
shapiro(np.random.uniform(-1,1,1000))
# Out:
# (0.9590712785720825, 4.12067446916469e-16)

# %%
filePath = 'https://raw.githubusercontent.com/micaelverissimo/ICA/master/EighthMixture100Stats.txt'
distDataFrame = pd.read_table(filePath, delimiter = '\s+', header = None)
mixtures = distDataFrame.values
print(distDataFrame.T.head())
# Out:
#           0              1         2          3         4
# 0  0.785424      12.777850  0.682670  13.435324  3.561111
# 1  0.842213  211467.214344  0.327126   1.918556  4.028181
# 2  0.185441       1.816125  0.298350   0.617460  1.095587
# 3  3.795056     354.440279  2.568090   0.822998  2.919371
# 4  2.175962       5.305139  0.395776   1.536879  3.468964

# %%
scatter_matrix(distDataFrame.T, alpha=0.4, diagonal = 'kde', figsize = (10,10))
plt.show()

# %%
resultsTable(mixtures)
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  Data</th><th style="text-align: right;">  Negentropy</th><th style="text-align: right;">  KL Divergence</th><th style="text-align: right;">  Shapiro-Wilk test W</th><th style="text-align: right;">  Shapiro-Wilk test P_value</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     0</td><td style="text-align: right;">     -0.0117</td><td style="text-align: right;">         1.1705</td><td style="text-align: right;">               0.8537</td><td style="text-align: right;">                 1.6325e-08</td></tr>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;">      1.4793</td><td style="text-align: right;">         3.1479</td><td style="text-align: right;">               0.2337</td><td style="text-align: right;">                 1.782e-20 </td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;">      0.7622</td><td style="text-align: right;">         3.0387</td><td style="text-align: right;">               0.6739</td><td style="text-align: right;">                 1.3836e-13</td></tr>
# <tr><td style="text-align: right;">     3</td><td style="text-align: right;">      1.2345</td><td style="text-align: right;">         2.7844</td><td style="text-align: right;">               0.5574</td><td style="text-align: right;">                 7.1617e-16</td></tr>
# <tr><td style="text-align: right;">     4</td><td style="text-align: right;">      0.521 </td><td style="text-align: right;">         1.6719</td><td style="text-align: right;">               0.7522</td><td style="text-align: right;">                 1.0718e-11</td></tr>
# </tbody>
# </table>

# %% [markdown]
# ## NPCA-RLS Algorithm

# %%
[yNPCA, WNPCA] = NPCA_RLS(mixtures,runs = 1)

# %%
scatter_matrix(pd.DataFrame(yNPCA.T), alpha = 0.4, diagonal = 'kde', figsize = (10,10))
plt.show()

# %%
resultsTable(yNPCA)
plot_MutualInformation(mixtures, y = yNPCA, KDE = True)
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  Data</th><th style="text-align: right;">  Negentropy</th><th style="text-align: right;">  KL Divergence</th><th style="text-align: right;">  Shapiro-Wilk test W</th><th style="text-align: right;">  Shapiro-Wilk test P_value</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     0</td><td style="text-align: right;">      0