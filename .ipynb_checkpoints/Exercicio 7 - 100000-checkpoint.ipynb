# %% [markdown]
# # Exercício 7 de Análise de Componentes Independentes
# Pedro Bandeira de Mello Martins
#
# CPE 782 - Análise de Componentes Independentes
#
#
#
# Análise feita para 100000 amostras

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.linalg import inv
from scipy.cluster.vq import whiten
import pandas as pd
from pandas.plotting import scatter_matrix
from scipy.stats import entropy, chi2_contingency, shapiro

# %matplotlib inline
from evaluation import calculateNegentropy, kde_entropy, KLdivergence, resultsTable, plot_MutualInformation
from ICAfunctions import cichocki_Feedback, cichocki_Feedforward, NPCA_RLS

#Notes:
#SHAPIRO: The algorithm used is described in [R634] but censoring parameters as 
#        described are not implemented. For N > 5000 the W test statistic is 
#        accurate but the p-value may not be.

# %%
learning_rate = 1e-6
gaussian_distribution = np.random.normal(0,1,1000)
shapiro(np.random.uniform(-1,1,1000))
# Out:
# (0.9572482705116272, 1.6963119876567027e-16)

# %%
filePath = 'https://raw.githubusercontent.com/micaelverissimo/ICA/master/SeventhMixture100000Stats.txt'
distDataFrame = pd.read_table(filePath, delimiter = '\s+', header = None)
mixtures = distDataFrame.values
print(distDataFrame.T.head())
# Out:
#           0          1         2         3
# 0 -0.296326  12.528742  1.738127  4.104600
# 1 -3.800073   4.700101  4.345100 -4.266835
# 2 -3.450606  13.031610  2.732976  0.182080
# 3 -3.052638  12.674063  2.572892 -0.166281
# 4 -0.289505  -3.235363 -0.150129 -2.664857

# %%
scatter_matrix(distDataFrame.T, alpha=0.4, diagonal = 'kde', figsize = (10,10))
plt.show()

# %%
resultsTable(mixtures)
# Out:
# C:\Users\Pedro\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1326: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# <table>
# <thead>
# <tr><th style="text-align: right;">  Data</th><th style="text-align: right;">  Negentropy</th><th style="text-align: right;">  KL Divergence</th><th style="text-align: right;">  Shapiro-Wilk test W</th><th style="text-align: right;">  Shapiro-Wilk test P_value</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     0</td><td style="text-align: right;">      0.3324</td><td style="text-align: right;">         0.4609</td><td style="text-align: right;">               0.9895</td><td style="text-align: right;">                    0      </td></tr>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;">      0     </td><td style="text-align: right;">         0.0224</td><td style="text-align: right;">               1     </td><td style="text-align: right;">                    0.99897</td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;">      0.2176</td><td style="text-align: right;">        28.3555</td><td style="text-align: right;">               0.9083</td><td style="text-align: right;">                    0      </td></tr>
# <tr><td style="text-align: right;">     3</td><td style="text-align: right;">      0.3858</td><td style="text-align: right;">         0.1061</td><td style="text-align: right;">               0.9905</td><td style="text-align: right;">                    0      </td></tr>
# </tbody>
# </table>

# %% [markdown]
# ## NPCA-RLS Algorithm

# %%
[yNPCA, WNPCA] = NPCA_RLS(mixtures, runs = 1)
# Out:
# Execution time: 7.101302146911621 seconds

# %%
scatter_matrix(pd.DataFrame(yNPCA.T), alpha = 0.4, diagonal = 'kde', figsize = (10,10))
plt.show()

# %%
resultsTable(yNPCA)
plot_MutualInformation(mixtures[-1000:], y = yNPCA[-1000:], KDE = False)
# Out:
# C:\Users\Pedro\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1326: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# <table>
# <thead>
# <tr><th style="text-align: right;">  Data</th><th style="text-align: right;">  Negentropy</th><th style="text-align: right;">  KL Divergence</th><th style="text-align: right;">  Shapiro-Wilk test W</th><th style="text-align: right;">  Shapiro-Wilk test P_value</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     0</td><td style="text-align: right;">      4.3317</td><td style="text-align: right;">        10.0344</td><td style="text-align: right;">               0.003 </td><td style="text-align: right;">                          0</td></tr>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;">      4.2629</td><td style="text-align: right;">         4.0293</td><td style="text-align: right;">               0.0119</td><td style="text-align: right;">                          0</td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;">      4.2993</td><td style="text-align: right;">         3.6952</td><td style="text-align: right;">               0.0092</td><td style="text-align: right;">                          0</td></tr>
# <tr><td style="text-align: right;">     3</td><td style="text-align: right;">      4.3095</td><td style="text-align: right;">         3.8776</td><td style="text-align: right;">               0.0095</td><td style="text-align: right;">                          0</td></tr>
# </tbody>
# </table>
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-8-2a93c4331422> in <module>()
#       1 resultsTable(yNPCA)
# ----> 2 plot_MutualInformation(mixtures[-1000:], y = yNPCA[-1000:], KDE = False)
#
# E:\OneDrive\Documentos\UFRJ\Mestrado\PEE\ICA\funcoes\evaluation.py in plot_MutualInformation(mixtures, y, KDE, nbins)
#     132     axs[0].set_title('Mutual Information: mixed signals')
#     133
# --> 134     sb.heatmap(mutualInformation_matrix(y, kde = KDE, n_bins = nbins), ax=axs[1], annot=True, cmap = 'YlGnBu', vmin = 0, vmax = 1)
#     135     axs[1].set_title('Mutual Information: outputs')
#     136
#
# E:\OneDrive\Documentos\UFRJ\Mestrado\PEE\ICA\funcoes\evaluation.py in mutualInformation_matrix(signal, kde, n_bins)
#     103                 fx, binsx = np.histogram(p, bins = p_bins)
#     104                 fy, binsy = np.histogram(q, bins = q_bins)
# --> 105                 fyx, binsy, binsx = np.histogram2d(q, p, bins = (binsy, binsx))
#     106
#     107                 pyx = fyx * 1. / cols
#
# C:\Users\Pedro\Anaconda3\lib\site-packages\numpy\lib\twodim_base.py in histogram2d(x, y, bins, range, normed, weights)
#     647         xedges = yedges = asarray(bins, float)
#     648         bins = [xedges, yedges]
# --> 649     hist, edges = histogramdd([x, y], bins, range, normed, weights)
#     650     return hist, edges[0], edges[1]
#     651
#
# C:\Users\Pedro\Anaconda3\lib\site-packages\numpy\lib\function_base.py in histogramdd(sample, bins, range, normed, weights)
#     975     # Reshape is used so that overlarge arrays
#     976     # will raise an error.
# --> 977     hist = zeros(nbin, float).reshape(-1)
#     978
#     979     # Compute the sample indices in the flattened histogram matrix.
#
# MemoryError:

# %% [markdown]
# ## Chichocki-Unbehauen Algorithm Feedback network

# %%
[yFeedback, WFeedback] = cichocki_Feedback(mixtures, runs  = 1)
# Out:
# Execution time: 9.634881258010864 seconds

# %%
scatter_matrix(pd.DataFrame(yFeedback.T), alpha = 0.4, diagonal = 'kde', figsize = (10,10))
plt.show()

# %%
resultsTable(yFeedback)
plot_MutualInformation(mixtures[-1000:], y = yFeedback[-1000:], KDE = False)
# Out:
# C:\Users\Pedro\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1326: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# <table>
# <thead>
# <tr><th style="text-align: right;">  Data</th><th style="text-align: right;">  Negentropy</th><th style="text-align: right;">  KL Divergence</th><th style="text-align: right;">  Shapiro-Wilk test W</th><th style="text-align: right;">  Shapiro-Wilk test P_value</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     0</td><td style="text-align: right;">      0     </td><td style="text-align: right;">         0.0368</td><td style="text-align: right;">               1     </td><td style="text-align: right;">                     0.7294</td></tr>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;">      0.3236</td><td style="text-align: right;">         0.2205</td><td style="text-align: right;">               0.9686</td><td style="text-align: right;">                     0     </td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;">      0.3505</td><td style="text-align: right;">         0.1059</td><td style="text-align: right;">               0.9905</td><td style="text-align: right;">                     0     </td></tr>
# <tr><td style="text-align: right;">     3</td><td style="text-align: right;">      0     </td><td style="text-align: right;">         0.1469</td><td style="text-align: right;">               0.9818</td><td style="text-align: right;">                     0     </td></tr>
# </tbody>
# </table>

# %% [markdown]
# ## Chichocki-Unbehauen Algorithm Feedforward network

# %%
[yFeedforward, WFeedforward] = cichocki_Feedforward(mixtures, learningRate = 1e-11, runs = 1)
# Out:
# Execution time: 7.036387205123901 seconds

# %%
scatter_matrix(pd.DataFrame(yFeedforward.T), alpha = 0.4, diagonal = 'kde', figsize = (10,10))
plt.show()

# %%
resultsTable(yFeedforward)
plot_MutualInformation(mixtures[-1000:], y = yFeedforward[-1000:], KDE = False)
# Out:
# C:\Users\Pedro\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1326: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# <table>
# <thead>
# <tr><th style="text-align: right;">  Data</th><th style="text-align: right;">  Negentropy</th><th style="text-align: right;">  KL Divergence</th><th style="text-align: right;">  Shapiro-Wilk test W</th><th style="text-align: right;">  Shapiro-Wilk test P_value</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     0</td><td style="text-align: right;">      0     </td><td style="text-align: right;">         0.026 </td><td style="text-align: right;">               1     </td><td style="text-align: right;">                    0.41093</td></tr>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;">      0.3403</td><td style="text-align: right;">         0.8572</td><td style="text-align: right;">               0.9602</td><td style="text-align: right;">                    0      </td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;">      0.3771</td><td style="text-align: right;">         0.2287</td><td style="text-align: right;">               0.9877</td><td style="text-align: right;">                    0      </td></tr>
# <tr><td style="text-align: right;">     3</td><td style="text-align: right;">      0     </td><td style="text-align: right;">         0.2646</td><td style="text-align: right;">               0.9802</td><td style="text-align: right;">                    0      </td></tr>
# </tbody>
# </table>
